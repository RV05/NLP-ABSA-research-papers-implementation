# %% [markdown]
# <a href="https://colab.research.google.com/github/RV05/NLP-ABSA-research-papers-implementation/blob/main/RGAT_ABSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/muyeby/RGAT-ABSA.git
# Out:
# Cloning into 'RGAT-ABSA'...
# remote: Enumerating objects: 394, done.
# remote: Counting objects: 100% (264/264), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 394 (delta 112), reused 210 (delta 76), pack-reused 130
# Receiving objects: 100% (394/394), 61.85 MiB | 22.01 MiB/s, done.
# Resolving deltas: 100% (142/142), done.

# %%
# !wget https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
# !bash Miniforge3-Linux-x86_64.sh -b
# Out:
# --2021-12-29 18:27:46--  https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/conda-forge/miniforge/releases/download/4.11.0-0/Miniforge3-Linux-x86_64.sh [following]
# --2021-12-29 18:27:46--  https://github.com/conda-forge/miniforge/releases/download/4.11.0-0/Miniforge3-Linux-x86_64.sh
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %%bash
# ~/miniforge3/bin/conda init
# Out:
# no change     /root/miniforge3/condabin/conda
# no change     /root/miniforge3/bin/conda
# no change     /root/miniforge3/bin/conda-env
# no change     /root/miniforge3/bin/activate
# no change     /root/miniforge3/bin/deactivate
# no change     /root/miniforge3/etc/profile.d/conda.sh
# no change     /root/miniforge3/etc/fish/conf.d/conda.fish
# no change     /root/miniforge3/shell/condabin/Conda.psm1
# no change     /root/miniforge3/shell/condabin/conda-hook.ps1
# no change     /root/miniforge3/lib/python3.9/site-packages/xontrib/conda.xsh
# no change     /root/miniforge3/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# !conda config --add channels conda-forge 
# !conda config --set channel_priority strict
# Out:
# /bin/bash: conda: command not found
# /bin/bash: conda: command not found

# %%
print("""
BONJOUR !
Sur le coté il y a un lien "add comment" qui permet de commenter pour les visiteurs :-)
""")
# Out:
# BONJOUR !
# Sur le coté il y a un lien "add comment" qui permet de commenter pour les visiteurs :-)

# %%
# !/root/miniforge3/condabin/conda update -y conda -n base
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /root/miniforge3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cryptography-36.0.1        |   py39h95dcef6_0         1.7 MB  conda-forge
#     setuptools-60.1.0          |   py39hf3d152e_0        1020 KB  conda-forge
#     wheel-0.37.1               |     pyhd8ed1ab_0          31 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.7 MB
#
# The following packages will be UPDATED:
#
#   cryptography                        36.0.0-py39h95dcef6_0 --> 36.0.1-py39h95dcef6_0
#   setuptools                          59.4.0-py39hf3d152e_0 --> 60.1.0-py39hf3d152e_0
#   wheel                                 0.37.0-pyhd8ed1ab_1 --> 0.37.1-pyhd8ed1ab_0
#
#
#
# ...

# %%
# !/root/miniforge3/condabin/conda env create -f /content/RGAT-ABSA/requirements.yaml
# Out:
# done
# done
#
# ...
# joblib-1.0.0         | 208 KB    | : 100% 1.0/1 [00:00<00:00,  3.73it/s]
# scipy-1.5.2          | 14.4 MB   | : 100% 1.0/1 [00:00<00:00,  1.55it/s]
# tk-8.6.10            | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  3.40it/s]
# openssl-1.1.1i       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.41it/s]
# libedit-3.1.20191231 | 116 KB    | : 100% 1.0/1 [00:00<00:00,  6.79it/s]
# threadpoolctl-2.1.0  | 17 KB     | : 100% 1.0/1 [00:00<00:00,  6.51it/s]
# wheel-0.36.2         | 33 KB     | : 100% 1.0/1 [00:00<00:00,  8.39it/s]
# ca-certificates-2020 | 121 KB    | : 100% 1.0/1 [00:00<00:00,  7.22it/s]
# cffi-1.14.4          | 223 KB    | : 100% 1.0/1 [00:00<00:00,  7.14it/s]
# mkl_random-1.1.1     | 327 KB    | : 100% 1.0/1 [00:00<00:00,  7.93it/s]
# libffi-3.3           | 50 KB     | : 100% 1.0/1 [00:00<00:00,  8.19it/s]
# mkl-service-2.3.0    | 52 KB     | : 100% 1.0/1 [00:00<00:00,  8.78it/s]
# libstdcxx-ng-9.1.0   | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  4.65it/s]
# ...

# %%
# !bash /root/miniforge3/bin/activate py36torch1.2new

# %%
cd /content/RGAT-ABSA
# Out:
# /content/RGAT-ABSA

# %%
# !bash /content/RGAT-ABSA/build_vocab.sh
# Out:
# loading files...
# 34164 tokens from 1980 examples loaded from dataset/Biaffine/glove/Restaurants/train.json.
# 9809 tokens from 599 examples loaded from dataset/Biaffine/glove/Restaurants/test.json.
# building vocab...
# token_vocab: 4521, pos_vocab: 46, dep_vocab: 35, post_vocab: 160, pol_vocab: 3
# dumping to files...
# Saving vocab to: dataset/Biaffine/glove/Restaurants/vocab_tok.vocab
# Saving vocab to: dataset/Biaffine/glove/Restaurants/vocab_pos.vocab
# Saving vocab to: dataset/Biaffine/glove/Restaurants/vocab_dep.vocab
# Saving vocab to: dataset/Biaffine/glove/Restaurants/vocab_post.vocab
# Saving vocab to: dataset/Biaffine/glove/Restaurants/vocab_pol.vocab
# all done.
# loading files...
# 28476 tokens from 1454 examples loaded from dataset/Biaffine/glove/Laptops/train.json.
# 6510 tokens from 409 examples loaded from dataset/Biaffine/glove/Laptops/test.json.
# building vocab...
# token_vocab: 3525, pos_vocab: 46, dep_vocab: 34, post_vocab: 168, pol_vocab: 3
# ...

# %%
cd /content/RGAT-ABSA/RGAT-BERT
# Out:
# /content/RGAT-ABSA/RGAT-BERT

# %%
pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.4 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 36.1 MB/s
# ...
#      |████████████████████████████████| 61 kB 472 kB/s
# ...
#      |████████████████████████████████| 895 kB 44.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 49.4 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !bash run-MAMS-BERT.sh
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# -----------  Configuration Arguments -----------
# att_dropout: 0.0
# batch_size: 16
# bert_lr: 2e-05
# bert_out_dim: 100
# ...

# %%
cd /content/RGAT-ABSA/RGAT-GloVe
# Out:
# /content/RGAT-ABSA/RGAT-GloVe

# %%
# !bash run-MAMS-glove.sh
